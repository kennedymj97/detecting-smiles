# %% [markdown]
# # Training Resnet18 to recognize smiling faces

# %%
# %matplotlib inline
# %load_ext autoreload
# %autoreload 2

# %%
from fastai import *
from fastai.vision import *
import torch

# %%
if torch.cuda.is_available():
    torch.cuda.set_device(0)

# %% [markdown]
# ## Data Augmentation

# %%
path = './data/happyunhappy/'

# %%
tfms = get_transforms(max_lighting=0.3, max_rotate=30, max_zoom=0, do_flip=True, flip_vert=False, max_warp=0.2, \
                      p_affine=0.75, p_lighting=0.75)

# %%
data = ImageDataBunch.from_folder(path, ds_tfms=tfms, size=64)
data.normalize(imagenet_stats)

# %%
data.show_batch(3)

# %%
learn = create_cnn(data, models.resnet18, pretrained=True, metrics=[accuracy])

# %%
# learn.lr_find()
# learn.recorder.plot()

# %%
learn.fit_one_cycle(10, 1e-2)

# %%
preds,y,losses = learn.get_preds(with_loss=True)
interp = ClassificationInterpretation(data, preds, y, losses)

# %%
interp.plot_top_losses(4, figsize=(7, 7), largest=True)

# %%
interp.plot_top_losses(4, figsize=(7, 7), largest=False)

# %%
interp.plot_confusion_matrix()

# %%
learn.save('happy_aug')

# %% [markdown]
# ## Fine-Tuning

# %%
learn.load('happy_aug')

# %%
learn.unfreeze()

# %%
learn.fit_one_cycle(10, 1e-3)
# Out:
# Total time: 01:15
# epoch  train_loss  valid_loss  accuracy
# 1      0.225624    0.448218    0.867647  (00:09)
# 2      0.230190    0.395420    0.857266  (00:07)
# 3      0.231091    0.193936    0.939446  (00:07)
# 4      0.215585    0.159769    0.947232  (00:07)
# 5      0.194638    0.202840    0.916090  (00:07)
# 6      0.196777    0.163676    0.937716  (00:07)
# 7      0.181704    0.135053    0.948962  (00:07)
# 8      0.149524    0.136822    0.948962  (00:07)
# 9      0.137380    0.148998    0.942042  (00:07)
# 10     0.118236    0.127233    0.954152  (00:07)

# %%
preds,y,losses = learn.get_preds(with_loss=True)
interp = ClassificationInterpretation(data, preds, y, losses)

# %%
interp.plot_top_losses(9, largest=True)

# %%
interp.plot_top_losses(9, largest=False)

# %%
interp.plot_confusion_matrix()

# %%
learn.save('happy_aug_ft')

# %% [markdown]
# ## Convert to onnx

# %%
from torch.autograd import Variable
import torch.onnx
import torchvision
import os

# %%
learn.load('happy_aug_ft')

# %%
dummy_input = Variable(torch.randn(64, 3, 64, 64))
input_names = [ "actual_input_1" ]
output_names = [ "output1" ]

# %%
if not os.path.isdir('./onnx_models/'):
    os.mkdir('./onnx_models/')
    
torch.onnx.export(learner_resnet18.model,dummy_input,'./onnx_models/happy.onnx', verbose=True, \
                  input_names=input_names, output_names=output_names)
